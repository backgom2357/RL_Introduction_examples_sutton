# %% [markdown]
# # 2.8 Gradient Bendit Algorithm

# %%
import numpy as np
import os
from tqdm import tqdm_notebook

np.random.seed(77)

import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 15
plt.rcParams['ytick.labelsize'] = 15
plt.rcParams["figure.figsize"] = (11,4)

plt.rcParams['axes.unicode_minus'] = False

PROJECT_ROOT_DIR = "."
CHAPTER_ID = '10_armed_testbed'

def save_fig(fig_id, tight_layout=True):
    path = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID, fig_id + ".png")
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format='png', dpi=300)

# %%
def get_reward(action):
    return np.random.normal(q_rewards[action],1)

def probability_action(action, H):
    numerator = np.e**(H[action])
    dominator = sum([np.e**x for x in H])
    return numerator/dominator

def cap_1(selected_action, action):
    if selected_action == action:
        return 1
    else:
        return 0
    
def argmax(array):
    top_index = [0]
    top = array[0]
    
    for i in range(1,len(array)):
        if array[i] > top:
            top_index = [i]
            top = array[i]
        elif array[i] == top:
            top_index.append(i)
        
    np.random.shuffle(top_index)
        
    return top_index[0]

# %%
## Gradient Bandit Algorithms
STEP = 1000
RUN = 1000
NUM_OF_ACTION = 10

q_rewards = []
for _ in range(NUM_OF_ACTION):
    tmp = np.random.normal(4,1)
    q_rewards.append(tmp)
    
optimal_action = np.argmax(q_rewards)

GB01_OPTIMAL_ACTIONS = [0]*STEP
GB01_OPTIMAL_ACTIONS_NoBase = [0]*STEP
GB04_OPTIMAL_ACTIONS = [0]*STEP
GB04_OPTIMAL_ACTIONS_NoBase = [0]*STEP

## 10-armed testbed
for i in tqdm_notebook(range(RUN)):

    # α=0.1
    H = [0]*NUM_OF_ACTION
    step_size = 0.1
    Q = 0

    for t in range(STEP):
        
        pi = [probability_action(x,H) for x in range(NUM_OF_ACTION)]

        A = np.random.choice(NUM_OF_ACTION,p=pi)
        R = get_reward(A)
        Q = (Q*(t) + R)/(t+1)
        baseline = R-Q

        for a in range(NUM_OF_ACTION):
            H[a] = H[a] + step_size*(baseline)*(cap_1(A,a) - probability_action(a,H))

        if A == optimal_action:
            GB01_OPTIMAL_ACTIONS[t] += 1/RUN*100
            
            
    # α=0.1, withdout baseline
    H = [0]*NUM_OF_ACTION
    step_size = 0.1
    
    for t in range(STEP):
        pi = [probability_action(x,H) for x in range(NUM_OF_ACTION)]

        A = np.random.choice(NUM_OF_ACTION,p=pi)
        R = get_reward(A)

        for a in range(NUM_OF_ACTION):
            H[a] = H[a] + step_size*(R)*(cap_1(A,a) - probability_action(a,H))

        if A == optimal_action:
            GB01_OPTIMAL_ACTIONS_NoBase[t] += 1/RUN*100
            
            
    # α=0.4
    H = [0]*NUM_OF_ACTION
    Q = 0
    step_size = 0.4
    
    for t in range(STEP):
        pi = [probability_action(x,H) for x in range(NUM_OF_ACTION)]

        A = np.random.choice(NUM_OF_ACTION,p=pi)
        R = get_reward(A)
        Q = (Q*(t) + R)/(t+1)
        baseline = R-Q

        for a in range(NUM_OF_ACTION):
            H[a] = H[a] + step_size*(baseline)*(cap_1(A,a) - probability_action(a,H))

        if A == optimal_action:
            GB04_OPTIMAL_ACTIONS[t] += 1/RUN*100
            
            
    # α=0.4, without baseline
    H = [0]*NUM_OF_ACTION
    step_size = 0.4
    
    for t in range(STEP):
        pi = [probability_action(x,H) for x in range(NUM_OF_ACTION)]

        A = np.random.choice(NUM_OF_ACTION,p=pi)
        R = get_reward(A)

        for a in range(NUM_OF_ACTION):
            H[a] = H[a] + step_size*(R)*(cap_1(A,a) - probability_action(a,H))

        if A == optimal_action:
            GB04_OPTIMAL_ACTIONS_NoBase[t] += 1/RUN*100
# Out:
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))

# %%
colors = ["#4076ff", "#b3c8ff", "#ffb24d", "#ffddb0"]
plt.plot(np.arange(STEP), GB01_OPTIMAL_ACTIONS, color=colors[0])
plt.plot(np.arange(STEP), GB04_OPTIMAL_ACTIONS, color=colors[1])
plt.plot(np.arange(STEP), GB01_OPTIMAL_ACTIONS_NoBase, color=colors[2])
plt.plot(np.arange(STEP), GB04_OPTIMAL_ACTIONS_NoBase, color=colors[3])
plt.legend(["α=0.1","α=0.4","α=0.1 without baseline","α=0.4 without baseline"])
plt.xlabel("Steps")
plt.ylabel("% Optimal action")
save_fig("GB_Otimal action")
plt.show()
